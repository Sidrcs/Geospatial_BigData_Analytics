# %% [markdown]
# ### Task 1: Visualization Human Mobility data from GeoDS Lab

# %%
import pandas as pd
import numpy as np
import wget, os, json
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# Data loaded from SafeGraph GeoDS@UW-Madison Lab - <a href = "https://github.com/GeoDS/COVID19USFlows"> GitHub </a>

# %%
# checks the file and download if it not present in the path

file = "weekly_ct2ct_2021_07_05_0.csv"
if not os.path.exists(file):
    url = "https://raw.githubusercontent.com/GeoDS/COVID19USFlows-WeeklyFlows-Ct2021/master/weekly_flows/ct2ct/2021_07_05/weekly_ct2ct_2021_07_05_0.csv"
    wget.download(url)
else:
    print(f"file exists in path:{os.getcwd()}+\+{file}")
# Out:
# file exists in path:C:\Users\Sidrcs\Documents\Github\Geospatial_BigData_Analytics\BigdataVisualization+\+weekly_ct2ct_2021_07_05_0.csv

# %%
# read and display the downloaded csv
flow_df = pd.read_csv("weekly_ct2ct_2021_07_05_0.csv")
flow_df.head()

# %% [markdown]
# For visualization in <a href = "https://kepler.gl/demo"> kepler.gl </a>, preprocessing SafeGraph data. Also, finding unique and most frequent geoid origin through <code>value_counts()</code> method. For the given dataset, it is based in <b> Orange county, FL</b>. Therefore, the origin geoid is <code>12095017103</code>

# %%
flow_df.geoid_o.value_counts()
# Out:
# 12095017103    2438
# 48157673101    2026
# 48439114103    1490
# 48339692001    1438
# 48157673200    1366
#                ...
# 1047957200       31
# 1097007700       30
# 23009966400      28
# 1087231700       14
# 2188000200       11
# Name: geoid_o, Length: 2179, dtype: int64

# %%
flow_df.dtypes # determines data types present
# Out:
# geoid_o                             int64
# geoid_d                             int64
# lng_o                             float64
# lat_o                             float64
# lng_d                             float64
# lat_d                             float64
# number_devices_primary_daytime      int64
# date_range                         object
# visitor_flows                       int64
# pop_flows                         float64
# dtype: object

# %%
# type casting origin county and destination geoids to string
flow_df['geoid_o']=flow_df['geoid_o'].apply(lambda x: str(x).zfill(11))
flow_df['geoid_d']=flow_df['geoid_d'].apply(lambda x: str(x).zfill(11))

# %%
# to confirm conversion
flow_df.dtypes
# Out:
# geoid_o                            object
# geoid_d                            object
# lng_o                             float64
# lat_o                             float64
# lng_d                             float64
# lat_d                             float64
# number_devices_primary_daytime      int64
# date_range                         object
# visitor_flows                       int64
# pop_flows                         float64
# dtype: object

# %%
flow_df.head(5)
# Out:
#        geoid_o      geoid_d      lng_o      lat_o      lng_d      lat_d  \
# 0  01001020100  01001020100 -86.490076  32.477185 -86.490076  32.477185
# 1  01001020100  01001020200 -86.490076  32.477185 -86.473375  32.474248
# 2  01001020100  01001020300 -86.490076  32.477185 -86.460190  32.475428
# 3  01001020100  01001020400 -86.490076  32.477185 -86.443624  32.472001
# 4  01001020100  01001020500 -86.490076  32.477185 -86.422661  32.458833
#
#    number_devices_primary_daytime           date_range  visitor_flows  \
# 0                             227  07/05/21 - 07/11/21             74
# 1                             227  07/05/21 - 07/11/21             70
# 2                             227  07/05/21 - 07/11/21            156
# 3                             227  07/05/21 - 07/11/21             91
# 4                             227  07/05/21 - 07/11/21            425
#
#    pop_flows
# 0      691.0
# 1      654.0
# 2     1458.0
# 3      850.0
# 4     3973.0

# %% [markdown]
# Slicing the data from one origin geoid to several destination geoids based most frequent origin geoid in the dataset. It is in Orange county, FL

# %%
# slicing flow_df based on geoid_o and geoid_d
one_flow_df = flow_df[(flow_df["geoid_o"].str.startswith("12095016902")) & flow_df["geoid_d"].str.startswith("12095")]

# %%
# exporting to csv for Kepler.gl visualization
one_flow_df.to_csv('Kepler_viz_data.csv')

# %% [markdown]
# ### Arc lines are based on population flow between origin geoid and destination geoids in Orange county, FL

# %% [markdown]
# <img src = "https://github.com/Sidrcs/Geospatial_BigData_Analytics/blob/main/BigdataVisualization/CensusTractFlowViz.png?raw=true"></img>

# %% [markdown]
# ### Task 2: Using pydeck to visualize SafeGraph human mobility flow data

# %%
import pydeck as pdk
import pandas as pd

# data from URL mentioned in task 1
data = r"weekly_ct2ct_2021_07_05_0.csv"

# visual bounding box range of northeast longitude and latitude, southwest longitude and latitude
bbox = [-81.5,28.5,-80,30.5]

# function to determine if the lng_o, lat_o is in bbox range
def in_bounding_box(point):
    lng, lat = point
    in_lng_bounds = bbox[0] <= lng <= bbox[2]
    in_lat_bounds = bbox[1] <= lat <= bbox[3]
    return in_lng_bounds and in_lat_bounds

# read csv data
df = pd.read_csv(data)
df.head()
# Out:
#       geoid_o     geoid_d      lng_o      lat_o      lng_d      lat_d  \
# 0  1001020100  1001020100 -86.490076  32.477185 -86.490076  32.477185
# 1  1001020100  1001020200 -86.490076  32.477185 -86.473375  32.474248
# 2  1001020100  1001020300 -86.490076  32.477185 -86.460190  32.475428
# 3  1001020100  1001020400 -86.490076  32.477185 -86.443624  32.472001
# 4  1001020100  1001020500 -86.490076  32.477185 -86.422661  32.458833
#
#    number_devices_primary_daytime           date_range  visitor_flows  \
# 0                             227  07/05/21 - 07/11/21             74
# 1                             227  07/05/21 - 07/11/21             70
# 2                             227  07/05/21 - 07/11/21            156
# 3                             227  07/05/21 - 07/11/21             91
# 4                             227  07/05/21 - 07/11/21            425
#
#    pop_flows
# 0      691.0
# 1      654.0
# 2     1458.0
# 3      850.0
# 4     3973.0

# %%
# testing function if it returns true or false
in_bounding_box([-81,30])
# Out:
# True

# %%
# restrict longitude, latitude based on bbox range
df = df[df[["lng_o", "lat_o"]].apply(lambda row: in_bounding_box(row), axis=1)]
df = df[df[["lng_d", "lat_d"]].apply(lambda row: in_bounding_box(row), axis=1)]
df.head()
# Out:
#             geoid_o      geoid_d      lng_o      lat_o      lng_d      lat_d  \
# 106925  12035060304  12035060106 -81.148074  29.446423 -81.199675  29.624888
# 106929  12035060304  12109021301 -81.148074  29.446423 -81.337244  29.845330
# 106932  12035060304  12109020400 -81.148074  29.446423 -81.314830  29.884354
# 106933  12035060304  12109020500 -81.148074  29.446423 -81.299035  29.887330
# 106934  12035060304  12109020901 -81.148074  29.446423 -81.422316  29.996587
#
#         number_devices_primary_daytime           date_range  visitor_flows  \
# 106925                             132  07/05/21 - 07/11/21             29
# 106929                             132  07/05/21 - 07/11/21             20
# 106932                             132  07/05/21 - 07/11/21              4
# 106933                             132  07/05/21 - 07/11/21              4
# 106934                             132  07/05/21 - 07/11/21              8
#
#         pop_flows
# 106925      456.0
# 106929      314.0
# 106932       62.0
# 106933       62.0
# 106934      125.0

# %% [markdown]
# <code>pdk.Layer()</code> generates arc layers (flow lines) between origin and destination points. There are parameters within <code>pdk.Layer()</code> method that customizes arc lines. <code>pdk.ViewState()</code> showcases display parameters of interactive HTML map. And <code>pdk.Deck()</code> binds the hover popup to the map. Lastly, <code>to_html()</code> creates a stand-alone HTML file and save it to the path.

# %%
# band colors for arc lines
green_band = [0, 255, 0, 40]
red_band = [240, 100, 0, 40]

# specify a deck.gl ArcLayer
arc_layer = pdk.Layer(
    "ArcLayer",
    data=df, # loaded dataframe within bbox view
    get_width="2", # width of each arc
    get_source_position=["lng_o", "lat_o"], # specific origin longitude, latitude
    get_target_position=["lng_d", "lat_d"], # specific destination longitude, latitude
    get_tilt=15, # determines the title of arc
    get_source_color=green_band, # color for origin arc
    get_target_color=red_band, # color for destination arc
    pickable=True,
    auto_highlight=True,
)

# determine display parameters
view_state = pdk.ViewState(latitude=29, longitude=-80.5, bearing=45, pitch=50, zoom=7)

# text to displayed on hover
text = {"html": "{visitor_flows} visitors <br /> commuter origin is red; commuter destination is green"}
r = pdk.Deck(arc_layer, initial_view_state=view_state, tooltip=text)

# renders interactive HTML 
r.to_html("arc_layer.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 45,
#     &quot;latitude&quot;: 29,
#     &quot;longitude&quot;: -80.5,
#     &quot;pitch&quot;: 50,
#     &quot;zoom&quot;: 7
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ArcLayer&quot;,
#       &quot;autoHighlight&quot;: true,
#       &quot;data&quot;: [
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12035060106,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.62488829410937,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.19967470300749,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 456.0,
#           &quot;visitor_flows&quot;: 29
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12109021301,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.84532967938501,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.33724376165269,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 314.0,
#           &quot;visitor_flows&quot;: 20
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12109020400,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.884354113730488,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.3148296910355,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 62.0,
#           &quot;visitor_flows&quot;: 4
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12109020500,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.88732954195116,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.29903538679979,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 62.0,
#           &quot;visitor_flows&quot;: 4
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12109020901,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.99658713119489,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.42231563787357,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 125.0,
#           &quot;visitor_flows&quot;: 8
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12109021101,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.677786013168284,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.42144215056105,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 78.0,
#           &quot;visitor_flows&quot;: 5
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12127081200,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.230688787524667,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.01296929109574,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 62.0,
#           &quot;visitor_flows&quot;: 4
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12009069901,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 28.572488034178427,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -80.70329265975045,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 62.0,
#           &quot;visitor_flows&quot;: 4
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12127092500,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.17949155008498,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.05669792886617,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 644.0,
#           &quot;visitor_flows&quot;: 41
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12127080400,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.30085835865006,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.04794005032159,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 173.0,
#           &quot;visitor_flows&quot;: 11
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12035060107,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.56904859445076,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.21711071660499,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 959.0,
#           &quot;visitor_flows&quot;: 61
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12009071400,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 28.58733823759077,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -80.79689208988253,
#           &quot;lng_o&quot;: -81.1480738641221,
#           &quot;number_devices_primary_daytime&quot;: 132,
#           &quot;pop_flows&quot;: 62.0,
#           &quot;visitor_flows&quot;: 4
#         },
#         {
#           &quot;date_range&quot;: &quot;07/05/21 - 07/11/21&quot;,
#           &quot;geoid_d&quot;: 12127082301,
#           &quot;geoid_o&quot;: 12035060304,
#           &quot;lat_d&quot;: 29.20566114508428,
#           &quot;lat_o&quot;: 29.44642326520931,
#           &quot;lng_d&quot;: -81.08051874006667,
#           &quot

# %% [markdown]
# ### Task 3: Using DataShader create a population density map of Madison, WI

# %%
# load all required libraries
import functools
import colorcet
import datashader as ds
import datashader.transfer_functions as tf
from colorcet import fire
from datashader.utils import export_image
from datashader.colors import colormap_select, Greys9

# %%
df = pd.read_csv(r"census-midwest.csv")
df.head()
# Out:
#          west      north race
# 0 -11443499.0  5927269.0    w
# 1 -11443482.0  5927260.0    w
# 2 -11443420.0  5927274.5    w
# 3 -11443353.0  5927362.0    w
# 4 -11443336.0  5927350.0    w

# %%
# bounds of USA, LakeMichigan, Chicago(IL), Madison(WI)
# Take Northeast, Southwest bounds and order them by (min long, max long), (min lat, max last)
USA           = ((-124.72,  -66.95), (23.55, 50.06))
Madison       = (( -89.60,  -89.21), (43.00, 43.14))

# converts lng, lat input (Web Mercator) to UTM meters
from datashader.utils import lnglat_to_meters as webm
# creates a list comprehension that unpacks to x_range (lng), y_range (lat)
x_range,y_range = [list(r) for r in webm(*USA)]

# determines height and width of the plot
plot_width  = int(900)
plot_height = int(plot_width*7.0/12)

# black background for generated raster
background = "black"

# %%
from functools import partial 
from datashader.utils import export_image # exports image
from datashader.colors import colormap_select, Greys9 #colormap_select allows to select colors based on function
from IPython.display import HTML, display

# storing the functions to variables
export = partial(export_image, background = background, export_path="export")
cm = partial(colormap_select, reverse=(background!="black"))

# adjusts width within jupyter notebook to display the rendered image
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# creates canvas for display
cvs = ds.Canvas(plot_width, plot_height, *webm(*USA))\

# input the data as points to canvas
agg = cvs.points(df, 'west', 'north')

# %%
# create and export a gray scale image for USA
export(tf.shade(agg, cmap = cm(Greys9,0.2), how='eq_hist'),"midwest_gray_eq_hist")
# Out:
# <xarray.Image (north: 525, west: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * west     (west) float64 -1.388e+07 -1.387e+07 ... -7.464e+06 -7.456e+06
#   * north    (north) float64 2.702e+06 2.709e+06 ... 6.446e+06 6.453e+06

# %%
if background == "black":
      color_key = {'w':'aqua', 'b':'lime',  'a':'red', 'h':'fuchsia', 'o':'yellow' }
else: color_key = {'w':'blue', 'b':'green', 'a':'red', 'h':'orange',  'o':'saddlebrown'}

# %%
# assigns 'race' column as a category type
df['race'] = df['race'].astype('category')

# %%
def create_image(longitude_range, latitude_range, w=plot_width, h=plot_height, method = 'eq_hist'):
    x_range,y_range=webm(longitude_range,latitude_range)
    cvs = ds.Canvas(plot_width=w, plot_height=h, x_range=x_range, y_range=y_range)
    agg = cvs.points(df, 'west', 'north', ds.count_cat('race'))
    img = tf.shade(agg, color_key=color_key, how=method)
    return img

# %%
# %%time
export(create_image(*USA),"Midwest")
# Out:
# CPU times: total: 1.64 s
# Wall time: 1.67 s
# <xarray.Image (north: 525, west: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * west     (west) float64 -1.388e+07 -1.387e+07 ... -7.464e+06 -7.456e+06
#   * north    (north) float64 2.702e+06 2.709e+06 ... 6.446e+06 6.453e+06

# %% [markdown]
# <p>Eq_hist method equalizes histogram of values for display such an optimum display is generated. I could infer other values present in the image in addition to most frequent value and can be used in cases to achieve overview and equalized approach for understanding a spatial context.</p>

# %%
# eq_hist method is a default method as it produces best results for an overview
export(create_image(*Madison),"Madison_eq_hist")
# Out:
# <xarray.Image (north: 525, west: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4280821760, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4280821760, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * west     (west) float64 -9.974e+06 -9.974e+06 ... -9.931e+06 -9.931e+06
#   * north    (north) float64 5.312e+06 5.312e+06 ... 5.333e+06 5.333e+06

# %% [markdown]
# <p>Linear method calibrates maximum intensity as 255 and minimum intensity as 0. Therefore, produces a linear scale of color values in our case from 0-255. The key findings when linear method is applied would be finding clusters of highest values or hotspots within raster.</p>

# %%
# linear method
export(create_image(*Madison, method = "linear"),"Madison_linear")
# Out:
# <xarray.Image (north: 525, west: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4280821760, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4280821760, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * west     (west) float64 -9.974e+06 -9.974e+06 ... -9.931e+06 -9.931e+06
#   * north    (north) float64 5.312e+06 5.312e+06 ... 5.333e+06 5.333e+06

# %% [markdown]
# <p>log scale method also applies a similar approach to intensity of values. Instead of linear scaling, logarithmic scaling is applied across the frequency of the repeated values. From this approach, under-represented data would not be part of the image and only repeating values would be present. log method eliminates noise and helps to understand dense neighborhoods of the analyzed bounding box</p>

# %%
# log method
export(create_image(*Madison, method = "log"),"Madison_log")
# Out:
# <xarray.Image (north: 525, west: 900)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4280821760, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4280821760, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * west     (west) float64 -9.974e+06 -9.974e+06 ... -9.931e+06 -9.931e+06
#   * north    (north) float64 5.312e+06 5.312e+06 ... 5.333e+06 5.333e+06
